# %% [markdown]
# # Importações

# %%
# first run
# !pip install numpy librosa pandas matplotlib
# Out:
# Requirement already satisfied: numpy in /home/duvrdx/anaconda3/lib/python3.9/site-packages (1.21.5)
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /home/duvrdx/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: matplotlib in /home/duvrdx/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scipy>=1.2.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (1.7.3)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.0 MB/s eta 0:00:01
# Collecting soundfile>=0.10.2
#   Downloading soundfile-0.11.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: decorator>=4.0.10 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.45.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: packaging>=20.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from librosa) (21.3)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 6.4 MB/s eta 0:00:01
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: setuptools in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: appdirs>=1.3.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: six>=1.5 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /home/duvrdx/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=61b4163a9908dee9e30aa92270411c2c3a8692e0d08f2a56ef971cbcd7b54d47
#   Stored in directory: /home/duvrdx/.cache/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: soundfile, resampy, pooch, audioread, librosa
# Successfully installed audioread-3.0.0 librosa-0.9.2 pooch-1.6.0 resampy-0.4.2 soundfile-0.11.0

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import os
import time
import IPython
import config

# %matplotlib inline

# %% [markdown]
# ## Lendo arquivo de audio

# %%
# AUDIO_FILE = './src/1759.wav'
AUDIO_FILE = librosa.ex('trumpet')
samples, sample_rate = librosa.load(AUDIO_FILE, sr=None)


print("Example shape:", samples.shape, "\nSample rate:", sample_rate, "\nData type:", type(samples))
# Out:
# Downloading file 'sorohanro_-_solo-trumpet-06.ogg' from 'https://librosa.org/data/audio/sorohanro_-_solo-trumpet-06.ogg' to '/home/duvrdx/.cache/librosa'.
# Example shape: (117601,)
# Sample rate: 22050
# Data type: <class 'numpy.ndarray'>

# %% [markdown]
# ### Audio

# %%
IPython.display.Audio(AUDIO_FILE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Waveplot

# %%
#import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveshow(samples, sr=sample_rate)

# %% [markdown]
# ## Espectogramas

# %% [markdown]
# ###  Short-term Fourier Transform

# %%
sgram = np.abs(librosa.stft(samples))
librosa.display.specshow(sgram)

# %% [markdown]
# - Usando a conversão de amplitude para decibéis. A conversão é feita assim como na documentação [librosa](https://librosa.org/doc/main/generated/librosa.stft.html)

# %%
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(sgram, ref=np.max), y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')

fig.colorbar(img, ax=ax, format="%+2.0f dB")
print(librosa.amplitude_to_db(sgram, ref=np.max).shape)
# Out:
# (1025, 230)

# %% [markdown]
# ### Mel-frequency spectogram

# %% [markdown]
# **Leitura e conversão segundo [Towards Data Science](https://towardsdatascience.com/audio-deep-learning-made-simple-part-2-why-mel-spectrograms-perform-better-aad889a93505)**

# %%
sgram_mag, _ = librosa.magphase(sgram)
mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sample_rate)
librosa.display.specshow(mel_scale_sgram)
print(mel_scale_sgram)

# %% [markdown]
# **Leitura e conversão segundo [documentação da biblioteca](https://librosa.org/doc/main/generated/librosa.feature.melspectrogram.html#librosa.feature.melspectrogram)**

# %%
fig, ax = plt.subplots()

mel_scale_sgram_dB = librosa.power_to_db(mel_scale_sgram, ref=np.max)

img = librosa.display.specshow(mel_scale_sgram_dB, x_axis='time', y_axis='mel', sr=sample_rate, fmax=8000, ax=ax)

fig.colorbar(img, ax=ax, format='%+2.0f dB')

ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]

# %%
fig, ax = plt.subplots()

y, sr = librosa.load(librosa.ex('trumpet'))
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
S_dB = librosa.power_to_db(S, ref=np.max)

img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]

# %% [markdown]
# ## Chromas

# %% [markdown]
# ###  Short-term Fourier Transform

# %%
fig, ax = plt.subplots()
chroma = librosa.feature.chroma_stft(S=sgram, sr=sample_rate)
img = librosa.display.specshow(chroma, y_axis='chroma', x_axis='time', ax=ax)

fig.colorbar(img, ax=[ax])
